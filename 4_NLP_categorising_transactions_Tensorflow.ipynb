# %% [markdown]
# # Import Libraries and Data

# %%
import os
import pickle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
# import data
# Load the files
with open('./pkl_data/bristol_spending_data.pkl', 'rb') as pickle_file:
    df = pickle.load(pickle_file)    
with open('./pkl_data/bristol_spending_data_daily.pkl', 'rb') as pickle_file:
    df_daily = pickle.load(pickle_file)
with open('./pkl_data/bristol_spending_data_monthly.pkl', 'rb') as pickle_file:
    df_monthly = pickle.load(pickle_file)

# %% [markdown]
# # NLP
# Lets make a NLP model to see if we can find trends in the supplier names and descriptions

# %% [markdown]
# ## Tokenizing the supplier names

# %%
# set parameters of tokenizer
NUMWORDS = 10000
OOV_TOK = "<OOV>"
tokenizer = Tokenizer(num_words=NUMWORDS, oov_token=OOV_TOK)

# %% [markdown]
# ### Coverting data to strings in order to tokenize
# When I was trying to tokenize the description columns I was getting an error as some of the values were floats instead of strings. We're trying to tokenize this data so we need to convert it first.
#
# Lets check what sort of data we have in these columns.

# %%
# define a function to count the data types
def count_datatypes(val):
    if isinstance(val, float):
        return 'float'
    elif isinstance(val, int):
        return 'int'
    elif isinstance(val, str):
        return 'str'
    else:
        return 'other'

# The column we want to look at
column = 'Description 1'

# apply the function to each element of the column.
datatype_counts = df[column].apply(count_datatypes)

# count the occurrences of each data type
float_count = (datatype_counts == 'float').sum().sum()
int_count = (datatype_counts == 'int').sum().sum()
str_count = (datatype_counts == 'str').sum().sum()

print(f'Data types in the {column} column:\n')
print('Floats: ', float_count)
print('Ints: ', int_count)
print('Strings: ', str_count)

# print out the rows where we are getting floats
float_rows = df[df[column].apply(lambda x: isinstance(x, float))]

print('\n\nThe rows containing float values:')
print(float_rows)
# Out:
# Data types in the Description 1 column:
#
# Floats:  8
# Ints:  0
# Strings:  1022705
#
#
# The rows containing float values:
#                                         Supplier    Amount   Pay Date  \
# 60235                     Creative Youth Network   1081.99 2022-04-25
# 163006                      OPUS Claim Solutions   1331.02 2020-11-11
# 166575  Arthur J.Gallagher Insurance Brokers Ltd  17300.00 2020-10-28
# 167118  Arthur J.Gallagher Insurance Brokers Ltd  55208.16 2020-10-23
# 171961                               Wansbroughs   4422.00 2020-09-29
# 171962                               Wansbroughs  -4422.00 2020-09-29
# 172129                      OPUS Claim Solutions    474.20 2020-09-28
# 172359                      OPUS Claim Solutions    455.84 2020-09-25
#
#        Description 1                       Description 2 Description 3
# 60235            NaN                                 NaN
# 163006           NaN  Insurance Fund - holding account 1
# 166575           NaN  Insurance Fund - holding account 1
# 167118           NaN  Insurance Fund - holding account 1
# 171961           NaN  Insurance Fund - holding account 1
# 171962           NaN  Insurance Fund - holding account 1
# 172129           NaN  Insurance Fund - holding account 1
# 172359           NaN  Insurance Fund - holding account 1

# %% [markdown]
# From this investigaton we can see the floats are related to data without a description (NaN values). So we can convert these to strings so that we can tokenize everything. We'll use the fill NaN function from pandas to do this.

# %%
# we want to tokenize the supplier data and descriptions 1-3
# create a list of the data we want to tokenize

column_list = ['Supplier', 'Description 1', 'Description 2', 'Description 3']
tokenized_data = {}

# convert each column to a numpy array, tokenize andd then store
for item in column_list:
    
    # fill NaN values with a string
    df[item] = df[item].fillna('NaN')
    
    # convert each column to a numpy array
    sentences = df[item].to_numpy()

    # tokenize the supplier data
    tokenizer.fit_on_texts(sentences)

    # create sequences using the new word index
    sequences = tokenizer.texts_to_sequences(sentences)
    tokenized_data[item] = pad_sequences(sequences, padding='post')

    # check out the most common words
    # word_index is sorted with the most common words appearing first
    print(f'Word index of the {item} column in descending order of frequency:\n{tokenizer.word_index}\n')

    # we can also see all the word counts using this
    print(f'Word counts in the {item} column:\n{tokenizer.word_counts}\n')

    # check out the max length of the supplier names (remeber: we have already padded the data to fit it to the max length)
    print(f'Max length in the {item} column:\n{len(tokenized_data[item][0])}\n\n')
# Out:
# Word index of the Supplier column in descending order of frequency:
# {'<OOV>': 1, 'ltd': 2, 'a': 3, 't': 4, 'care': 5, 'limited': 6, 'bristol': 7, 'services': 8, 'trust': 9, 'the': 10, 'plc': 11, 'housing': 12, 'redacted': 13, 'staffing': 14, 'guidant': 15, 'carlisle': 16, 'uk': 17, 'global': 18, 'randstad': 19, 'homes': 20, 'group': 21, 'family': 22, 'maples': 23, 'brandon': 24, 'home': 25, 'plumbing': 26, 'connolly': 27, 'callaghan': 28, 'house': 29, 'community': 30, 'healthcare': 31, 'and': 32, 'contractors': 33, '21': 34, 'properties': 35, 'hudson': 36, 'west': 37, 'milestones': 38, 'st': 39, 'rental': 40, 'school': 41, 'south': 42, 'alex': 43, 'fry': 44, 'for': 45, 'fostering': 46, 'heating': 47, 'property': 48, 'm': 49, 'solutions': 50, 'holdings': 51, 'step': 52, 'glevum': 53, 'mimosa': 54, 'second': 55, 'of': 56, 'support': 57, 'residential': 58, 'e': 59, 'maintenance': 60, 'centre': 61, 'health': 62, 'nursery': 63, 'somerset': 64, 'north': 65, 's': 66, 'national': 67, 'association': 68, 'co': 69, 'flooring': 70, 'council': 71, 'electrical': 72, 'education': 73, 'systems': 74, 'r': 75, 'academy': 76, 'people': 77, 'bupa': 78, 'carpentry': 79, 'nursing': 80, 'company': 81, '1st': 82, 'ashcroft': 83, 'construction': 84, 'day': 85, 'foster': 86, 'city': 87, 'j': 88, 'avon': 89, 'gloucestershire': 90, 'business': 91, 'energy': 92, 'fantasy': 93, 'cedar': 94, 'cabot': 95, 'c': 96, 'college': 97, 'carewatch': 98, 'environmental': 99, 'management': 100, 'builders': 101, 'field': 102, 'security': 103, 'four': 104, 'foundation': 105, 'wolseley': 106, 'seasons': 107, 'sect': 108, '28': 109, 'court': 110, 'horfield': 111, 'eden': 112, 'williams': 113, 'agency': 114, 'finance': 115, 'thermals': 116, 'building': 117, 'decorating': 118, 'p': 119, 'd': 120, 'glazing': 121, 'park': 122, 'society': 123, 'recruitment': 124, 'tily': 125, 'ian': 126, 'brunelcare': 127, 'partnership': 128, 'foodservice': 129, 'ccg': 130, 'homecare': 131, 'new': 132, 'southern': 133, 'schools': 134, 'lodge': 135, 'saunders': 136, 'way': 137, 'methodist': 138, 'royal': 139, 'sons': 140, 'nhs': 141, 'contracting': 142, 'cleaning': 143, 'etm': 144, 'university': 145, 'lifestyle': 146, 'jeff': 147, 'b': 148, 'clc': 149, 'top': 150, 'drawer': 151, 'aspects': 152, 'media': 153, 'your': 154, 'freeways': 155, 'partnerships': 156, 'rent': 157, 'llp': 158, 'lovell': 159, 'h': 160, 'caring': 161, 'electric': 162, 'international': 163, 'farm': 164, 'childrens': 165, 'aged': 166, 'leonard': 167, 'w': 168, 'airtech': 169, 'cheshire': 170, 'cic': 171, 'gas': 172, 'decorators': 173, 'sri': 174, 'monica': 175, 'integral': 176, 'charles': 177, 'nobilis': 178, 'lloyds': 179, 'learning': 180, 'network': 181, 'car': 182, 'project': 183, 'independent': 184, 'places': 185, 'taxis': 186, 'specialist': 187, 'pharmacy': 188, 'tmp': 189, 'bell': 190, 'hill': 191, 'domestic': 192, 'amicus': 193, 'bros': 194, 'acct': 195, '1625': 196, 'drain': 197, 'n': 198, 'world': 199, 'westbury': 200, 'ashley': 201, 'bath': 202, 'shaw': 203, 'pre': 204, 'fire': 205, 'individual': 206, 'mencap': 207, 'alert': 208, 'priory': 209, 'double': 210, 'action': 211, 'consulting': 212, 'primary': 213, 'jewson': 214, 'commercial': 215, 'silva': 216, 'hire': 217, 'churchill': 218, 'stewart': 219, 'adolescent': 220, 'dean': 221, 'lorne': 222, 'brothers': 223, 'kumari': 224, 'tree': 225, 'pattersons': 226, 'children': 227, 'butcher': 228, 'hays': 229, 'kew': 230, 'account': 231, 'associates': 232, 'county': 233, 'apollo': 234, 'downs': 235, 'claro': 236, 'futures': 237, 'social': 238, 'pfi': 239, 'prospects': 240, 'improving': 241, "children's": 242, 'enterprise': 243, 'matters': 244, 'brightbow': 245, 'training': 246, 'designz': 247, 'calder': 248, 'gd': 249, 'practice': 250, 'wring': 251, 'scott': 252, 'gardiner': 253, 'green': 254, 'frenchay': 255, 'channel': 256, 'scaffolding': 257, '3': 258, 'east': 259, 'stephens': 260, 'supplies': 261, 'sellars': 262, 'road': 263, 'lancer': 264, 'products': 265, 'riversway': 266, 'virgin': 267, 'voyage': 268, 'raphael': 269, 'independence' ...
#
# Word counts in the Supplier column:
# OrderedDict([('milestones', 12527), ('trust', 58268), ('m', 9383), ('d', 4233), ('building', 4327), ('services', 69306), ('limited', 77335), ('ape', 687), ('fire', 2552), ('security', 4853), ('ltd', 401197), ('alfred', 441), ('bagnall', 440), ('sons', 3686), ('west', 13099), ('artspace', 156), ('lifespace', 88), ('ashcroft', 6152), ('ashley', 2660), ('guest', 1559), ('house', 22652), ('bpm', 138), ('contracting', 3670), ('barnardo', 164), ('connolly', 22798), ('callaghan', 22798), ('t', 87014), ('a', 92032), ('bristol', 76101), ('family', 25622), ('housing', 54071), ('natural', 206), ('history', 194), ('consortium', 1631), ('irish', 47), ('salt', 77), ('mining', 71), ('exploration', 47), ('co', 7173), ('burges', 139), ('salmon', 139), ('llp', 3279), ('clc', 3462), ('contractors', 17862), ('community', 22138), ('foster', 5872), ('care', 84785), ('c', 5026), ('r', 6583), ('fencing', 938), ('easy', 398), ('access', 1371), ('scaffolding', 1920), ('frenchay', 1934), ('taxis', 2896), ('redacted', 47442), ('top', 3444), ('drawer', 3432), ('properties', 14495), ('lancer', 1871), ('scott', 1952), ('windmill', 1042), ('hill', 2798), ('city', 5678), ('farm', 3173), ('clarkson', 142), ('ove', 691), ('arup', 692), ('partners', 1113), ('international', 3199), ('power', 1190), ('fixings', 62), ('signis', 161), ('reconstruct', 95), ('children', 2230), ('adult', 146), ('rider', 349), ('levett', 349), ('bucknall', 349), ('uk', 34279), ('safestore', 92), ('spaces', 101), ('safety', 650), ('green', 1941), ('j', 5657), ('scadding', 209), ('son', 854), ('sharpfibre', 552), ('wessex', 1415), ('lift', 1058), ('sports', 1159), ('heroes', 685), ('jeff', 3548), ('way', 3716), ('electrical', 6965), ('tily', 4041), ('carpentry', 6316), ('property', 9481), ('maintenance', 8218), ('ward', 383), ('company', 6180), ('letters', 374), ('whitehall', 292), ('printing', 346), ('avon', 5544), ('cathedral', 530), ('school', 11346), ('polydeck', 29), ('watson', 395), ('petroleum', 392), ('powred', 452), ('heating', 9499), ('components', 549), ('well', 423), ('pharmacy', 2838), ('badham', 85), ('aecom', 211), ('boots', 1219), ('lloyds', 2980), ('p', 4266), ('h', 3259), ('healthcare', 18257), ('easton', 949), ('day', 6019), ('and', 17904), ('night', 98), ('chemist', 181), ('bhogal', 87), ('dispensing', 87), ('john', 477), ('cabot', 5030), ('academy', 6573), ('foxes', 64), ('colas', 59), ('enviro', 87), ('technology', 1275), ('plc', 55092), ('red', 793), ('speed', 242), ('sulzer', 12), ('electro', 1), ('mechanical', 316), ('electrics', 1564), ('generators', 18), ('the', 58075), ('ombudsman', 10), ('charlton', 202), ('nursery', 7726), ('carlisle', 43873), ('staffing', 44365), ('guidant', 43901), ('global', 30031), ('gm', 9), ('engineering', 1382), ('marston', 175), ('group', 26390), ('construction', 6040), ('medical', 1558), ('expert', 33), ('witness', 14), ('alliance', 335), ('mouldex', 22), ('lorne', 2335), ('stewart', 2339), ('designz', 1993), ('parent', 468), ('support', 8334), ('project', 2927), ('envirocall', 524), ('arcadis', 383), ('latcham', 5), ('direct', 1625), ('lcb', 120), ('essential', 52), ('beauty', 13), ('wycliffe', 2), ('college', 4985), ('bertinet', 5), ('bakery', 7), ('kh', 1), ('alma', 3), ('physiotherapy', 7), ('afro', 3), ('street', 392), ('mila', 3), ('coffee', 22), ('national', 7504), ('grid', 25), ('electricity', 77), ('distribution', 726), ('southwest', 850), ('1st', 6167), ('choice', 1431), ('stairlifts', 979), ('livewest', 262), ('homes', 26461), ('acta', 68), ('theatre', 502), ('north', 7514), ('somerset', 7721), ('council', 7021), ('thermals', 4361), ("children's", 2061), ('playground', 27), ('dr', 669), ('karin', 12), ('denton', 33), ('devon', 469), ('county', 2176), ('etm', 3648), ('highline', 390), ('key', 986), ('2', 1178), ('futures', 2113), ('wiltshire', 1692), ('nelson', 877), ('we', 911), ('repair', 1004), ('proludic', 50), ('south', 10734), ('gloucestershire', 5528), ('schools', 3797), ('general', 261), ('account', 2195), ('univers ...
#
# Max length in the Supplier column:
# 13
#
#
# Word index of the Description 1 column in descending order of frequency:
# {'<OOV>': 1, 'ltd': 2, 'care': 3, 'tpp': 4, 's': 5, 'c': 6, 'only': 7, 'services': 8, 'h': 9, 'to': 10, 'payments': 11, 'r': 12, 'agency': 13, 'm': 14, 'a': 15, 'residential': 16, 'external': 17, 't': 18, 'fees': 19, 'departmental': 20, 'staff': 21, 'b': 22, 'limited': 23, 'bristol': 24, 'nursing': 25, 'response': 26, 'housing': 27, 'and': 28, 'support': 29, 'trust': 30, 'the': 31, 'renovation': 32, 'conversion': 33, 'plc': 34, 'home': 35, 'based': 36, 'redacted': 37, 'accommodation': 38, 'staffing': 39, 'guidant': 40, 'carlisle': 41, 'contractors': 42, 'charges': 43, 'community': 44, 'improvement': 45, 'service': 46, 'landlords': 47, 'costs': 48, 'users': 49, 'direct': 50, 'uk': 51, 'grants': 52, 'global': 53, 'randstad': 54, 'placement': 55, 'voluntary': 56, 'payment': 57, 'planned': 58, 'homes': 59, 'group': 60, 'family': 61, 'maples': 62, 'sums': 63, 'variable': 64, 'foster': 65, 'brandon': 66, 'p': 67, 'cap': 68, 'materials': 69, 'plumbing': 70, 'professional': 71, 'connolly': 72, 'callaghan': 73, 'house': 74, 'groups': 75, 'other': 76, 'supplies': 77, 'construction': 78, 'y': 79, 'outreach': 80, 'building': 81, 'healthcare': 82, 'new': 83, 'of': 84, 'payable': 85, 'improveme': 86, 'practice': 87, 'for': 88, 'day': 89, '21': 90, 'equipment': 91, 'extra': 92, 'properties': 93, 'hudson': 94, 'west': 95, 'rental': 96, 'maintenance': 97, 'milestones': 98, 'transport': 99, 'st': 100, 'consultants': 101, 'maint': 102, 'training': 103, 'school': 104, 'south': 105, 'alex': 106, 'fry': 107, 'health': 108, 'dept': 109, 'fostering': 110, 'heating': 111, 'property': 112, 'solutions': 113, 'holdings': 114, 'holding': 115, 'hire': 116, 'schools': 117, 'step': 118, 'contract': 119, 'glevum': 120, 'computing': 121, 'mimosa': 122, 'second': 123, 'expenses': 124, 'code': 125, 'purchase': 126, 'authorities': 127, 'e': 128, 'centre': 129, 'childrens': 130, 'cleaning': 131, 'nursery': 132, 'somerset': 133, 'accom': 134, 'north': 135, 'national': 136, 'f': 137, 'security': 138, 'association': 139, 'co': 140, 'flooring': 141, 'council': 142, 'local': 143, 'electrical': 144, 'computer': 145, 'assocns': 146, 'education': 147, 'furniture': 148, 'systems': 149, 'paid': 150, 'academy': 151, 'people': 152, 'out': 153, 'bupa': 154, 'carpentry': 155, 'company': 156, 'advertising': 157, '1st': 158, 'catering': 159, 'ashcroft': 160, 'management': 161, 'rent': 162, 'city': 163, 'business': 164, 'energy': 165, 'marketing': 166, 'j': 167, 'avon': 168, 'gas': 169, 'gloucestershire': 170, 'centres': 171, 'fantasy': 172, 'cedar': 173, 'resale': 174, 'printing': 175, 'maintained': 176, 'bcc': 177, 'use': 178, 'cabot': 179, 'college': 180, 'repair': 181, 'carewatch': 182, 'environmental': 183, 'builders': 184, 'field': 185, 'court': 186, 'internal': 187, 'four': 188, 'foundation': 189, 'term': 190, 'finance': 191, 'educ': 192, 'wolseley': 193, 'seasons': 194, 'sect': 195, '28': 196, 'horfield': 197, 'book': 198, 'eden': 199, 'williams': 200, 'equip': 201, 'mats': 202, 'electricity': 203, 'thermals': 204, 'non': 205, 'decorating': 206, 'd': 207, 'exps': 208, 'glazing': 209, 'long': 210, 'park': 211, 'society': 212, 'software': 213, 'recruitment': 214, 'tily': 215, 'ian': 216, 'brunelcare': 217, 'partnership': 218, 'foodservice': 219, 'vehicles': 220, 'ccg': 221, 'homecare': 222, 'independent': 223, 'southern': 224, 'comms': 225, 'lodge': 226, 'saunders': 227, 'way': 228, 'nhs': 229, 'stationery': 230, 'methodist': 231, 'royal': 232, 'sons': 233, 'contracting': 234, 'etm': 235, 'university': 236, 'lifestyle': 237, 'waste': 238, 'meals': 239, 'jeff': 240, 'clc': 241, 'top': 242, 'drawer': 243, 'tree': 244, 'office': 245, 'aspects': 246, 'media': 247, 'supported': 248, 'partnerships': 249, 'your': 250, 'freeways': 251, 'llp': 252, 'lovell': 253, 'caring': 254, 'client': 255, 'electric': 256, 'international': 257, 'farm': 258, 'taxis': 259, 'aged': 260, 'leonard': 261, 'w': 262, 'airtech': 263, 'cheshire': 264, 'cic': 265, 'decorators': 266, 'resp': 267, 'learning':  ...
#
# Word counts in the Description 1 column:
# OrderedDict([('milestones', 12527), ('trust', 58270), ('m', 103901), ('d', 4305), ('building', 19005), ('services', 158975), ('limited', 77335), ('ape', 687), ('fire', 2585), ('security', 7314), ('ltd', 401197), ('alfred', 441), ('bagnall', 440), ('sons', 3686), ('west', 13110), ('artspace', 156), ('lifespace', 88), ('ashcroft', 6152), ('ashley', 2660), ('guest', 1559), ('house', 22658), ('bpm', 138), ('contracting', 3670), ('barnardo', 164), ('connolly', 22798), ('callaghan', 22798), ('t', 87178), ('a', 98531), ('bristol', 76250), ('family', 25708), ('housing', 69389), ('natural', 206), ('history', 194), ('consortium', 1631), ('irish', 47), ('salt', 77), ('mining', 71), ('exploration', 47), ('co', 7173), ('burges', 139), ('salmon', 139), ('llp', 3279), ('clc', 3462), ('contractors', 43173), ('community', 41817), ('foster', 25215), ('care', 302466), ('c', 177893), ('r', 106587), ('fencing', 938), ('easy', 398), ('access', 1528), ('scaffolding', 1920), ('frenchay', 1934), ('taxis', 3175), ('redacted', 47443), ('top', 3460), ('drawer', 3432), ('properties', 14510), ('lancer', 1871), ('scott', 1952), ('windmill', 1043), ('hill', 2804), ('city', 5726), ('farm', 3176), ('clarkson', 142), ('ove', 691), ('arup', 692), ('partners', 1113), ('international', 3199), ('power', 1196), ('fixings', 62), ('signis', 161), ('reconstruct', 95), ('children', 3042), ('adult', 1166), ('rider', 349), ('levett', 349), ('bucknall', 349), ('uk', 34281), ('safestore', 92), ('spaces', 101), ('safety', 672), ('green', 2017), ('j', 5657), ('scadding', 209), ('son', 854), ('sharpfibre', 552), ('wessex', 1415), ('lift', 1059), ('sports', 1322), ('heroes', 685), ('jeff', 3548), ('way', 3719), ('electrical', 6986), ('tily', 4041), ('carpentry', 6316), ('property', 9675), ('maintenance', 12779), ('ward', 383), ('company', 6195), ('letters', 374), ('whitehall', 295), ('printing', 5145), ('avon', 5578), ('cathedral', 530), ('school', 11419), ('polydeck', 29), ('watson', 395), ('petroleum', 396), ('powred', 452), ('heating', 9740), ('components', 549), ('well', 423), ('pharmacy', 2838), ('badham', 85), ('aecom', 211), ('boots', 1219), ('lloyds', 2980), ('p', 24484), ('h', 154757), ('healthcare', 18257), ('easton', 950), ('day', 15106), ('and', 67913), ('night', 98), ('chemist', 181), ('bhogal', 87), ('dispensing', 87), ('john', 477), ('cabot', 5031), ('academy', 6583), ('foxes', 64), ('colas', 59), ('enviro', 87), ('technology', 1454), ('plc', 55092), ('red', 793), ('speed', 242), ('sulzer', 12), ('electro', 1), ('mechanical', 317), ('electrics', 1564), ('generators', 18), ('the', 58084), ('ombudsman', 10), ('charlton', 202), ('nursery', 7734), ('carlisle', 43873), ('staffing', 44375), ('guidant', 43901), ('global', 30031), ('gm', 9), ('engineering', 1424), ('marston', 175), ('group', 26390), ('construction', 20268), ('medical', 2731), ('expert', 33), ('witness', 14), ('alliance', 335), ('mouldex', 22), ('lorne', 2335), ('stewart', 2339), ('designz', 1993), ('parent', 1799), ('support', 63294), ('project', 3043), ('envirocall', 524), ('arcadis', 383), ('latcham', 5), ('direct', 34880), ('lcb', 120), ('essential', 54), ('beauty', 13), ('wycliffe', 2), ('college', 4989), ('bertinet', 5), ('bakery', 7), ('kh', 1), ('alma', 3), ('physiotherapy', 7), ('afro', 3), ('street', 397), ('mila', 3), ('coffee', 22), ('national', 7506), ('grid', 25), ('electricity', 4418), ('distribution', 726), ('southwest', 850), ('1st', 6167), ('choice', 1432), ('stairlifts', 979), ('livewest', 262), ('homes', 26467), ('acta', 68), ('theatre', 502), ('north', 7554), ('somerset', 7721), ('council', 7080), ('thermals', 4361), ("children's", 2079), ('playground', 27), ('dr', 669), ('karin', 12), ('denton', 33), ('devon', 469), ('county', 2176), ('etm', 3648), ('highline', 390), ('key', 991), ('2', 1213), ('futures', 2113), ('wiltshire', 1692), ('nelson', 877), ('we', 911), ('repair', 4959), ('proludic', 50), ('south', 10803), ('gloucestershire', 5528), ('schools', 8912), ('general', 1543), ('ac ...
#
# Max length in the Description 1 column:
# 12
#
#
# Word index of the Description 2 column in descending order of frequency:
# {'<OOV>': 1, 'ltd': 2, 'care': 3, 'tpp': 4, 'c': 5, 'services': 6, 's': 7, 'people': 8, 'only': 9, 'support': 10, 'h': 11, 'to': 12, 'housing': 13, 'm': 14, 'a': 15, 'payments': 16, 'r': 17, 'agency': 18, 'response': 19, 'external': 20, 'residential': 21, 'older': 22, 'learning': 23, 'bristol': 24, 'b': 25, 't': 26, 'health': 27, 'with': 28, 'capital': 29, 'fees': 30, 'and': 31, 'staff': 32, 'departmental': 33, 'limited': 34, 'nursing': 35, 'mental': 36, 'mi': 37, 'planned': 38, 'north': 39, 'repairs': 40, 'the': 41, 'trust': 42, 'renovation': 43, 'conversion': 44, 'difficulties': 45, 'plc': 46, 'home': 47, 'service': 48, 'south': 49, 'based': 50, 'accommodation': 51, '18': 52, 'school': 53, 'programme': 54, '64': 55, 'redacted': 56, 'community': 57, 'charges': 58, 'staffing': 59, 'guidant': 60, 'carlisle': 61, 'contractors': 62, 'improvement': 63, 'costs': 64, 'supported': 65, 'landlords': 66, 'direct': 67, 'funded': 68, 'users': 69, '65': 70, 'uk': 71, 'of': 72, 'needs': 73, 'relets': 74, 'payment': 75, 'other': 76, 'grants': 77, 'p': 78, 'placement': 79, 'global': 80, 'randstad': 81, 'primary': 82, 'physical': 83, 'interim': 84, 'disabled': 85, 'voluntary': 86, 'family': 87, 'general': 88, 'group': 89, 'homes': 90, 'block': 91, 'construction': 92, 'team': 93, 'disability': 94, 'fostering': 95, 'maples': 96, 'foster': 97, 'sums': 98, 'variable': 99, 'brandon': 100, 'for': 101, 'cap': 102, 'maintenance': 103, 'holding': 104, 'house': 105, 'materials': 106, 'building': 107, 'management': 108, 'plumbing': 109, 'professional': 110, 'connolly': 111, 'callaghan': 112, 'adaptations': 113, 'd': 114, 'y': 115, 'e': 116, 'new': 117, 'groups': 118, 'independent': 119, 'supplies': 120, 'practice': 121, 'outreach': 122, 'schools': 123, 'solutions': 124, 'healthcare': 125, 'op': 126, 'adults': 127, 'east': 128, 'west': 129, 'transport': 130, 'ey': 131, 'agencies': 132, 'payable': 133, 'improveme': 134, 'supporting': 135, 'code': 136, 'central': 137, 'properties': 138, 'equipment': 139, 'day': 140, '21': 141, 'centre': 142, 'extra': 143, 'city': 144, 'hudson': 145, 'st': 146, 'children': 147, 'vol': 148, 'orgs': 149, 'asylum': 150, 'rental': 151, 'property': 152, 'local': 153, 'training': 154, 'account': 155, 'mh': 156, 'milestones': 157, 'special': 158, 'purchase': 159, 'consultants': 160, 'energy': 161, 'maint': 162, 'out': 163, 'placements': 164, 'development': 165, 'assessment': 166, 'overheads': 167, 'dept': 168, 'finance': 169, 'alex': 170, 'fry': 171, 'grant': 172, 'social': 173, 'public': 174, 'cleaning': 175, 'fleet': 176, 'heating': 177, 'paint': 178, 'contract': 179, 'council': 180, 'expenditure': 181, 'office': 182, 'non': 183, 'education': 184, 'internal': 185, 'legal': 186, 'in': 187, 'access': 188, 'nursery': 189, 'catering': 190, '2': 191, 'control': 192, 'hire': 193, 'childrens': 194, 'holdings': 195, 'step': 196, 'project': 197, 'ld': 198, 'computing': 199, 'glevum': 200, 'mimosa': 201, 'security': 202, 'business': 203, 'misuse': 204, 'second': 205, 'expenses': 206, 'authorities': 207, 'centres': 208, 'electrical': 209, 'f': 210, 'after': 211, 'pvi': 212, 'design': 213, 'partnership': 214, 'waste': 215, 'technology': 216, 'somerset': 217, 'works': 218, 'accom': 219, 'looked': 220, 'hnb': 221, 'rent': 222, 'secondary': 223, 'national': 224, 'academy': 225, 'fund': 226, 'association': 227, 'co': 228, 'flooring': 229, 'work': 230, 'locality': 231, 'coroner': 232, 'computer': 233, 'projects': 234, 'systems': 235, 'net': 236, 'chc': 237, 'assocns': 238, 'investment': 239, 'grounds': 240, 'furniture': 241, 'seekers': 242, 'i': 243, 'paid': 244, 'park': 245, 'engineering': 246, 'top': 247, 'company': 248, 'use': 249, 'early': 250, 'bupa': 251, 'carpentry': 252, 'sec117': 253, 'pre': 254, 'advertising': 255, 'preparing': 256, 'adulthood': 257, '1st': 258, 'parks': 259, 'ashcroft': 260, 'immigration': 261, 'avon': 262, 'bcc': 263, 'court': 264, 'marketing': 265, 'funding': 266, 'old': 267, '16': 268, 'lodge': 269, 'point': 270, 'b ...
#
# Word counts in the Description 2 column:
# OrderedDict([('milestones', 12527), ('trust', 58590), ('m', 113678), ('d', 22406), ('building', 23903), ('services', 193420), ('limited', 77335), ('ape', 831), ('fire', 5420), ('security', 8533), ('ltd', 401198), ('alfred', 441), ('bagnall', 440), ('sons', 3686), ('west', 17948), ('artspace', 156), ('lifespace', 88), ('ashcroft', 6152), ('ashley', 2811), ('guest', 1559), ('house', 24420), ('bpm', 138), ('contracting', 3670), ('barnardo', 164), ('connolly', 22798), ('callaghan', 22798), ('t', 88727), ('a', 112889), ('bristol', 92431), ('family', 28741), ('housing', 116911), ('natural', 511), ('history', 200), ('consortium', 1631), ('irish', 47), ('salt', 77), ('mining', 71), ('exploration', 47), ('co', 7254), ('burges', 139), ('salmon', 139), ('llp', 3279), ('clc', 3462), ('contractors', 43715), ('community', 45792), ('foster', 25253), ('care', 309728), ('c', 204011), ('r', 109803), ('fencing', 938), ('easy', 401), ('access', 9509), ('scaffolding', 1920), ('frenchay', 2783), ('taxis', 3350), ('redacted', 47444), ('top', 6630), ('drawer', 3432), ('properties', 15815), ('lancer', 1871), ('scott', 1952), ('windmill', 1206), ('hill', 3176), ('city', 14445), ('farm', 3346), ('clarkson', 142), ('ove', 691), ('arup', 692), ('partners', 1123), ('international', 3331), ('power', 1207), ('fixings', 62), ('signis', 161), ('reconstruct', 108), ('children', 13319), ('adult', 2926), ('rider', 349), ('levett', 349), ('bucknall', 349), ('uk', 35043), ('safestore', 92), ('spaces', 126), ('safety', 4249), ('green', 4465), ('j', 5657), ('scadding', 209), ('son', 854), ('sharpfibre', 552), ('wessex', 1440), ('lift', 1411), ('sports', 3084), ('heroes', 685), ('jeff', 3548), ('way', 4033), ('electrical', 8326), ('tily', 4041), ('carpentry', 6390), ('property', 12834), ('maintenance', 24665), ('ward', 383), ('company', 6587), ('letters', 374), ('whitehall', 393), ('printing', 5145), ('avon', 5990), ('cathedral', 553), ('school', 49465), ('polydeck', 29), ('watson', 395), ('petroleum', 396), ('powred', 452), ('heating', 10132), ('components', 549), ('well', 423), ('pharmacy', 2838), ('badham', 85), ('aecom', 211), ('boots', 1219), ('lloyds', 2980), ('p', 30750), ('h', 155674), ('healthcare', 18257), ('easton', 1172), ('day', 15363), ('and', 82323), ('night', 107), ('chemist', 181), ('bhogal', 87), ('dispensing', 87), ('john', 477), ('cabot', 5171), ('academy', 7501), ('foxes', 64), ('colas', 59), ('enviro', 87), ('technology', 7970), ('plc', 55092), ('red', 842), ('speed', 317), ('sulzer', 12), ('electro', 1), ('mechanical', 759), ('electrics', 1564), ('generators', 18), ('the', 60069), ('ombudsman', 10), ('charlton', 202), ('nursery', 9450), ('carlisle', 43873), ('staffing', 44808), ('guidant', 43901), ('global', 30059), ('gm', 50), ('engineering', 6687), ('marston', 175), ('group', 28368), ('construction', 27851), ('medical', 2731), ('expert', 33), ('witness', 14), ('alliance', 365), ('mouldex', 22), ('lorne', 2335), ('stewart', 2339), ('designz', 1993), ('parent', 3261), ('support', 157490), ('project', 8815), ('envirocall', 524), ('arcadis', 383), ('latcham', 5), ('direct', 36245), ('lcb', 120), ('essential', 94), ('beauty', 13), ('wycliffe', 2), ('college', 5531), ('bertinet', 5), ('bakery', 7), ('kh', 1), ('alma', 3), ('physiotherapy', 7), ('afro', 3), ('street', 2595), ('mila', 3), ('coffee', 22), ('national', 7520), ('grid', 25), ('electricity', 4418), ('distribution', 726), ('southwest', 850), ('1st', 6167), ('choice', 1475), ('stairlifts', 979), ('livewest', 262), ('homes', 28038), ('acta', 68), ('theatre', 510), ('north', 62818), ('somerset', 7722), ('council', 9887), ('thermals', 4361), ("children's", 5459), ('playground', 28), ('dr', 669), ('karin', 12), ('denton', 33), ('devon', 469), ('county', 2192), ('etm', 3648), ('highline', 390), ('key', 2162), ('2', 9233), ('futures', 2270), ('wiltshire', 1692), ('nelson', 892), ('we', 968), ('repair', 5032), ('proludic', 50), ('south', 50192), ('gloucestershire', 5568), ('schools', 19532), ('gene ...
#
# Max length in the Description 2 column:
# 16
#
#
# Word index of the Description 3 column in descending order of frequency:
# {'<OOV>': 1, 'ltd': 2, 'care': 3, 'tpp': 4, 'c': 5, 'services': 6, 's': 7, 'nan': 8, 'people': 9, 'only': 10, 'support': 11, 'h': 12, 'to': 13, 'learning': 14, 'housing': 15, 'm': 16, 'a': 17, 'payments': 18, 'bristol': 19, 'r': 20, 'response': 21, 'agency': 22, 'external': 23, 'residential': 24, 'older': 25, 'difficulties': 26, 'b': 27, 'north': 28, 't': 29, 'health': 30, 'capital': 31, 'and': 32, 'with': 33, 'team': 34, 'fees': 35, 'staff': 36, 'departmental': 37, 'limited': 38, 'south': 39, 'planned': 40, 'nursing': 41, 'mental': 42, 'mi': 43, 'repairs': 44, 'the': 45, 'trust': 46, 'programme': 47, 'conversion': 48, 'renovation': 49, 'service': 50, 'plc': 51, 'school': 52, 'home': 53, 'primary': 54, 'assessment': 55, 'accommodation': 56, 'based': 57, '18': 58, '64': 59, 'locality': 60, 'redacted': 61, 'community': 62, 'charges': 63, 'staffing': 64, 'guidant': 65, 'carlisle': 66, 'contractors': 67, 'physical': 68, 'east': 69, 'improvement': 70, 'costs': 71, 'adaptations': 72, 'central': 73, '65': 74, 'supported': 75, 'general': 76, 'landlords': 77, 'direct': 78, 'of': 79, 'relets': 80, 'funded': 81, 'holding': 82, 'needs': 83, 'users': 84, 'disabled': 85, 'uk': 86, 'op': 87, 'payment': 88, 'grants': 89, 'other': 90, 'fostering': 91, 'p': 92, 'placement': 93, 'global': 94, 'randstad': 95, 'maintenance': 96, 'interim': 97, 'family': 98, 'voluntary': 99, 'construction': 100, 'management': 101, 'group': 102, 'block': 103, 'homes': 104, 'house': 105, 'e': 106, 'd': 107, 'disability': 108, 'heating': 109, 'for': 110, 'foster': 111, 'maples': 112, 'sums': 113, 'variable': 114, 'adults': 115, 'brandon': 116, 'cap': 117, 'code': 118, 'independent': 119, 'new': 120, 'materials': 121, 'building': 122, 'y': 123, 'plumbing': 124, 'west': 125, 'professional': 126, 'connolly': 127, 'callaghan': 128, 'agencies': 129, 'mh': 130, 'groups': 131, 'st': 132, 'supplies': 133, 'outreach': 134, 'solutions': 135, 'practice': 136, 'schools': 137, 'transport': 138, 'centre': 139, 'supporting': 140, 'healthcare': 141, 'citywide': 142, 'ey': 143, 'payable': 144, 'properties': 145, 'improveme': 146, 'contract': 147, 'grant': 148, 'in': 149, 'city': 150, 'n11': 151, 'impairment': 152, 'equipment': 153, 'hospital': 154, '2': 155, 'day': 156, 'special': 157, '21': 158, 'n12': 159, 'partnership': 160, 'extra': 161, 'royal': 162, 'hudson': 163, 'asylum': 164, 'partnerships': 165, 'energy': 166, 'children': 167, 'account': 168, 'local': 169, 'property': 170, 'secondary': 171, 'training': 172, 'development': 173, 'vol': 174, 'orgs': 175, 'nursery': 176, 'f': 177, 'rental': 178, 'park': 179, 'out': 180, 'milestones': 181, 'purchase': 182, 'placements': 183, 'paint': 184, 'legal': 185, 'consultants': 186, 'n1': 187, 'maint': 188, 'public': 189, 'education': 190, 'finance': 191, 'overheads': 192, 'project': 193, 'investment': 194, 'office': 195, 'works': 196, 'patch': 197, 'fund': 198, 'social': 199, 'non': 200, 'infirmary': 201, 's16': 202, 'n2': 203, 'dept': 204, 'alex': 205, 'fry': 206, 'southmead': 207, 'fleet': 208, 'cleaning': 209, 'computing': 210, 'internal': 211, 'council': 212, 'expenditure': 213, 'access': 214, 'design': 215, 'control': 216, 'catering': 217, 'major': 218, 'childrens': 219, 's1': 220, 'business': 221, 'bwp': 222, 'i': 223, 'hire': 224, '1': 225, 'holdings': 226, 'installs': 227, 'recovery': 228, 'ld': 229, 'step': 230, 's2': 231, 'security': 232, 'frenchay': 233, 'electrical': 234, 'projects': 235, 'centres': 236, 'gas': 237, 'waste': 238, 'misuse': 239, 'glevum': 240, 'mimosa': 241, 'second': 242, 'technology': 243, 'expenses': 244, "children's": 245, 'after': 246, 'authorities': 247, 'hospitals': 248, 'pvi': 249, 'replacement': 250, 'aowa': 251, 'early': 252, 'rent': 253, 'operations': 254, 'academy': 255, 'engineering': 256, 'work': 257, 'somerset': 258, 'coroner': 259, 'looked': 260, 'accom': 261, 'hnb': 262, 'blocks': 263, 'furniture': 264, 'national': 265, 'seekers': 266, 'court': 267, 'association': 268, 'n3': 269, 'co': 270, 'flo ...
#
# Word counts in the Description 3 column:
# OrderedDict([('milestones', 12527), ('trust', 59108), ('m', 117019), ('d', 27428), ('building', 24253), ('services', 198696), ('limited', 77342), ('ape', 867), ('fire', 6485), ('security', 8874), ('ltd', 401203), ('alfred', 441), ('bagnall', 440), ('sons', 3686), ('west', 23023), ('artspace', 156), ('lifespace', 88), ('ashcroft', 6152), ('ashley', 3403), ('guest', 1559), ('house', 28097), ('bpm', 138), ('contracting', 3670), ('barnardo', 164), ('connolly', 22798), ('callaghan', 22798), ('t', 89304), ('a', 115757), ('bristol', 112478), ('family', 29025), ('housing', 120836), ('natural', 811), ('history', 200), ('consortium', 1631), ('irish', 47), ('salt', 77), ('mining', 71), ('exploration', 47), ('co', 7256), ('burges', 139), ('salmon', 139), ('llp', 3279), ('clc', 3463), ('contractors', 43715), ('community', 47333), ('foster', 25624), ('care', 310634), ('c', 207415), ('r', 110281), ('fencing', 943), ('easy', 401), ('access', 9839), ('scaffolding', 1920), ('frenchay', 8862), ('taxis', 3350), ('redacted', 47633), ('top', 6656), ('drawer', 3432), ('properties', 17279), ('lancer', 1871), ('scott', 1952), ('windmill', 1323), ('hill', 5363), ('city', 16815), ('farm', 3794), ('clarkson', 142), ('ove', 691), ('arup', 692), ('partners', 1126), ('international', 3349), ('power', 1214), ('fixings', 62), ('signis', 161), ('reconstruct', 135), ('children', 13685), ('adult', 3636), ('rider', 349), ('levett', 349), ('bucknall', 349), ('uk', 35044), ('safestore', 92), ('spaces', 195), ('safety', 5226), ('green', 6807), ('j', 5658), ('scadding', 209), ('son', 854), ('sharpfibre', 552), ('wessex', 1440), ('lift', 1486), ('sports', 3888), ('heroes', 685), ('jeff', 3548), ('way', 4222), ('electrical', 8804), ('tily', 4041), ('carpentry', 6446), ('property', 13462), ('maintenance', 29441), ('ward', 383), ('company', 6605), ('letters', 374), ('whitehall', 860), ('printing', 5145), ('avon', 6458), ('cathedral', 778), ('school', 54574), ('polydeck', 29), ('watson', 395), ('petroleum', 396), ('powred', 452), ('heating', 25874), ('components', 549), ('well', 447), ('pharmacy', 2838), ('badham', 85), ('aecom', 211), ('boots', 1219), ('lloyds', 2980), ('p', 31533), ('h', 156969), ('healthcare', 18257), ('easton', 1696), ('day', 15811), ('and', 86210), ('night', 163), ('chemist', 181), ('bhogal', 87), ('dispensing', 87), ('john', 477), ('cabot', 5844), ('academy', 7817), ('foxes', 64), ('colas', 59), ('enviro', 87), ('technology', 8519), ('plc', 55092), ('red', 861), ('speed', 413), ('sulzer', 12), ('electro', 1), ('mechanical', 792), ('electrics', 1564), ('generators', 18), ('the', 62160), ('ombudsman', 11), ('charlton', 202), ('nursery', 13068), ('carlisle', 43873), ('staffing', 44816), ('guidant', 43901), ('global', 30059), ('gm', 634), ('engineering', 7815), ('marston', 175), ('group', 28519), ('construction', 28857), ('medical', 2731), ('expert', 33), ('witness', 14), ('alliance', 365), ('mouldex', 22), ('lorne', 2335), ('stewart', 2339), ('designz', 1993), ('parent', 3471), ('support', 165718), ('project', 11256), ('envirocall', 524), ('arcadis', 383), ('latcham', 5), ('direct', 37468), ('lcb', 120), ('essential', 111), ('beauty', 13), ('wycliffe', 2), ('college', 5600), ('bertinet', 5), ('bakery', 7), ('kh', 1), ('alma', 3), ('physiotherapy', 7), ('afro', 3), ('street', 4114), ('mila', 3), ('coffee', 22), ('national', 7525), ('grid', 25), ('electricity', 4418), ('distribution', 728), ('southwest', 890), ('1st', 6189), ('choice', 1539), ('stairlifts', 979), ('livewest', 262), ('homes', 28364), ('acta', 79), ('theatre', 533), ('north', 89555), ('somerset', 7722), ('council', 10081), ('thermals', 4361), ("children's", 8485), ('playground', 45), ('dr', 843), ('karin', 12), ('denton', 33), ('devon', 469), ('county', 2833), ('etm', 3648), ('highline', 390), ('key', 2188), ('2', 15817), ('futures', 2318), ('wiltshire', 1692), ('nelson', 907), ('we', 969), ('repair', 5120), ('proludic', 50), ('south', 76248), ('gloucestershire', 5583), ('schools', 19939), ...
#
# Max length in the Description 3 column:
# 14

# %% [markdown]
# # Unsupervised learning
# We want to try and classify the transactions (e.g. education, social care, housing). We can use unsupervised learning to first see if there are any trends in the data. Otherwise a semi-supervised learning model might be the way to go and I can manually label some of the transactions and use those labels to build a semi-supervised model.

# %%
# column to fit model to
column = 'Description 1'
data = tokenized_data[column]

kmeans = KMeans(n_clusters=6, random_state=42)
kmeans.fit(data)
# Out:
# /Users/samuelspeller/miniconda3/envs/tf_cpu/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=6, random_state=42)

# %%
# explore the clusters
print(kmeans.cluster_centers_)
print(kmeans.labels_)
# Out:
# [[ 3.09429012e+01  4.32585651e+01  2.98444729e+01  2.61038698e+01
#    2.04370304e+01  1.06888388e+01  4.83178530e+00  3.49197090e+00
#    4.14165703e+00  3.41889206e+00  1.70556747e+00  9.06399321e-01]
#  [ 8.05377130e+03  3.39668696e+02  1.62396522e+02  5.98860870e+01
#    2.40991304e+01  5.05495652e+01  2.34782609e-01 -1.55431223e-14
#   -7.99360578e-15 -2.66453526e-15 -1.86517468e-14 -5.55111512e-16]
#  [ 4.48958012e+02  4.39585768e+02  2.61361096e+02  1.38167509e+02
#    4.26384148e+01  1.51924968e+01  5.09178701e-01  6.47760397e-01
#    3.75870586e-01  4.96895930e-01  1.02140518e-14 -3.00870440e-14]
#  [ 2.80100915e+03  6.09411170e+02  3.29503611e+02  1.09322870e+03
#    6.82941743e+02  2.39075590e+02  1.53221955e+02  9.31805489e+01
#    5.04039480e+01  9.62927299e-04 -1.44328993e-14  1.22124533e-15]
#  [ 1.26541765e+03  9.09970588e+02  4.33381176e+03  7.27864706e+02
#    3.55326471e+02  1.51335294e+02  5.34632353e+01  3.85044118e+01
#    2.76176471e+01  2.26470588e-01 -1.04360964e-14 -5.21804822e-15]
#  [ 9.31561940e+02  3.59166493e+03  9.03356716e+02  4.76280597e+02
#    1.00421642e+02  6.35171642e+01  2.02634328e+01  3.89552239e-01
#    1.22462687e+00  1.42108547e-14 -2.17603713e-14  2.33146835e-15]]
# [0 0 0 ... 0 0 2]

# %%
# trying to compute silhouette score takes a long time.

# silhouette_score = silhouette_score(tokenized_data['Supplier'], kmeans.labels_)
# print(f"Silhouette score: {silhouette_score:.3f}")

labels = kmeans.labels_
for i in range(len(set(labels))):
    print(f"Cluster {i}:")
    # Print the transaction descriptions in each cluster
    descriptions = df[column][labels == i]
    print(descriptions)
    print()
# Out:
# Cluster 0:
# 0                     Services - Fees and Charges
# 1                     Services - Fees and Charges
# 2          R&M - Departmental response (external)
# 3          R&M - Departmental response (external)
# 4           R&M - Departmental planned (external)
#                             ...
# 1022707             PAYMENTS TO VOLUNTARY ASSOCNS
# 1022708             PAYMENTS TO VOLUNTARY ASSOCNS
# 1022709                              FEES PAYABLE
# 1022710          EQUIPMENT, FURNITURE & MATERIALS
# 1022711        C Y P S ONLY - TOPPING UP PAYMENTS
# Name: Description 1, Length: 972525, dtype: object
#
# Cluster 1:
# 5949                      Balances brought forward
# 60235                                          NaN
# 64409      TTP - HRA contributions to general fund
# 83745      TTP - HRA contributions to general fund
# 83941                           Members Allowances
#                             ...
# 1022406                            S2BS5N117170939
# 1022446                            S2BTDN1LB272687
# 1022447                            S2BTDN1LB272687
# 1022649                            S1BS5N120368465
# 1022650                            S1BS5N120368465
# Name: Description 1, Length: 1150, dtype: object
#
# Cluster 2:
# 89                                       Solid Fuel
# 227                                 Standing Charge
# 425                               Bicycle Allowance
# 484                   Vehicle Maintenance - Repairs
# 719        Vehicle Maintenance - Contract Additions
#                              ...
# 1022675             BUDGET HOLDING ACCOUNT (EXPEND)
# 1022676             BUDGET HOLDING ACCOUNT (EXPEND)
# 1022681      PRINTING, STATIONERY & GEN OFFICE EXPS
# 1022682      PRINTING, STATIONERY & GEN OFFICE EXPS
# 1022712                          STAFF EXPS - V A T
# Name: Description 1, Length: 44941, dtype: object
#
# Cluster 3:
# 408               Sale of Plants / Floral Displays
# 1525              Sale of Plants / Floral Displays
# 4349            Loans & Other Financial Assistance
# 5167                                     Input VAT
# 5323                         Compensation Payments
#                             ...
# 1021141                                 RECOVERIES
# 1021270    RECHARGES TO OTHER DEPARTMENTS (INCOME)
# 1022015                                 COMMISSION
# 1022079             RECHARGES WITHIN DEPT (INCOME)
# 1022166           LEASES - OPERATING LEASE CHARGES
# Name: Description 1, Length: 2077, dtype: object
#
# Cluster 4:
# 7832                                TPP - Placement NonLAC
# 7881                             Insurance - Bristol Motor
# 10431                                      MOT & HGV Tests
# 12737                      Vehicle Maintenance - Servicing
# 14291      Education trips, Holidays, Outings & Activities
#                                 ...
# 1017086                     PAYMENT TO RELATIVES AS CARERS
# 1017087                     PAYMENT TO RELATIVES AS CARERS
# 1017278                             PAYMENTS TO GOVT DEPTS
# 1017561                                    S117: S.GRIFFIN
# 1022189                     BALANCE B/FWD OR C/FWD 1 APRIL
# Name: Description 1, Length: 680, dtype: object
#
# Cluster 5:
# 3751               TPP - CIN  Allowance
# 6114             Section 106 agreements
# 6501             Section 106 agreements
# 7866             Section 106 agreements
# 9309       TPP - Intermediate care beds
#                        ...
# 1017806          DEPARTMENTAL OVERHEADS
# 1017807          DEPARTMENTAL OVERHEADS
# 1017813          DEPARTMENTAL OVERHEADS
# 1017816          DEPARTMENTAL OVERHEADS
# 1017825          DEPARTMENTAL OVERHEADS
# Name: Description 1, Length: 1340, dtype: object

# %% [markdown]
# # Semi Supervised Learning - BERT

# %% [markdown]
# I maually labelled some of the transactions in the data with categories that I obtained from the council's budget. The plan was to then use these labels to train the algorithm to label the unlabelled data.

# %%
#for downloading BERT
# pip install sentence_transformers
from sentence_transformers import SentenceTransformer

#for finding most similar text vectors
from sklearn.metrics.pairwise import cosine_similarity

#regular expressoin toolkit
import re

#NLP toolkits
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize

#for plotting expense categories later
import matplotlib.pyplot as plt 
plt.style.use('ggplot')
import seaborn as sns
import matplotlib
import matplotlib.ticker as ticker # for formatting major units on x-y axis
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/samuelspeller/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# import the semi-labelled data

df = pd.read_csv('./spending_data/bristol_spending_data_final_semi_labeled.csv')

# set non numeric values to n/a with errors=coerce
df['Amount'] = pd.to_numeric(df['Amount'], errors='coerce')

# convert the date to a datetime object
df['Pay Date']= pd.to_datetime(df['Pay Date'], format='%d/%m/%Y')

# check the df
print(df.info())

# Write to pickle pickle file
with open('./pkl_data/bristol_spending_data_semi_labelled.pkl', 'wb') as pickle_file:
    pickle.dump(df, pickle_file)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 # import the semi-labelled data
# ----> 3 df = pd.read_csv('./spending_data/bristol_spending_data_final_semi_labeled.csv')
#       5 # set non numeric values to n/a with errors=coerce
#       6 df['Amount'] = pd.to_numeric(df['Amount'], errors='coerce')
#
# NameError: name 'pd' is not defined

# %% [markdown]
# ## Download pre-trained BERT model.

# %%
# This may take some time to download and run 
# depending on the size of the input

bert_input = tokenized_data['Description 2'].tolist()
model = SentenceTransformer('paraphrase-mpnet-base-v2') 
embeddings = model.encode(bert_input, show_progress_bar = True)
embedding_BERT = np.array(embeddings)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 5
#       1 # This may take some time to download and run
#       2 # depending on the size of the input
#       4 bert_input = tokenized_data['Description 2'].tolist()
# ----> 5 model = SentenceTransformer('paraphrase-mpnet-base-v2')
#       6 embeddings = model.encode(bert_input, show_progress_bar = True)
#       7 embedding_BERT = np.array(embeddings)
#
# File ~/miniconda3/envs/tf_cpu/lib/python3.10/site-packages/sentence_transformers/SentenceTransformer.py:87, in SentenceTransformer.__init__(self, model_name_or_path, modules, device, cache_folder, use_auth_token)
#      83     model_path = os.path.join(cache_folder, model_name_or_path.replace("/", "_"))
#      85     if not os.path.exists(os.path.join(model_path, 'modules.json')):
#      86         # Download from hub with caching
# ---> 87         snapshot_download(model_name_or_path,
#      88                             cache_dir=cache_folder,
#      89                             library_name='sentence-transformers',
#      90                             library_version=__version__,
#      91                             ignore_files=['flax_model.msgpack', 'rust_model.ot', 'tf_model.h5'],
#      92                             use_auth_token=use_auth_token)
#      94 if os.path.exists(os.path.join(model_path, 'modules.json')):    #Load as SentenceTransformer model
#      95     modules = self._load_sbert_model(model_path)
#
# File ~/miniconda3/envs/tf_cpu/lib/python3.10/site-packages/sentence_transformers/util.py:491, in snapshot_download(repo_id, revision, cache_dir, library_name, library_version, user_agent, ignore_files, use_auth_token)
#     486 if version.parse(huggingface_hub.__version__) >= version.parse("0.8.1"):
#     487     # huggingface_hub v0.8.1 introduces a new cache layout. We sill use a manual layout
#     488     # And need to pass legacy_cache_layout=True to avoid that a warning will be printed
#     489     cached_download_args['legacy_cache_layout'] = True
# --> 491 path = cached_download(**cached_download_args)
#     493 if os.path.exists(path + ".lock"):
#     494     os.remove(path + ".lock")
#
# File ~/miniconda3/envs/tf_cpu/lib/python3.10/site-packages/huggingface_hub/utils/_validators.py:120, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     117 if check_use_auth_token:
#     118     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 120 return fn(*args, **kwargs)
#
# File ~/miniconda3/envs/tf_cpu/lib/python3.10/site-packages/huggingface_hub/file_download.py:800, in cached_download(url, library_name, library_version, cache_dir, user_agent, force_download, force_filename, proxies, etag_timeout, resume_download, token, local_files_only, legacy_cache_layout)
#     797 with temp_file_manager() as temp_file:
#     798     logger.info("downloading %s to %s", url, temp_file.name)
# --> 800     http_get(
#     801         url_to_download,
#     802         temp_file,
#     803         proxies=proxies,
#     804         resume_size=resume_size,
#     805         headers=headers,
#     806         expected_size=expected_size,
#     807     )
#     809 logger.info("storing %s in cache at %s", url, cache_path)
#     810 _chmod_and_replace(temp_file.name, cache_path)
#
# File ~/miniconda3/envs/tf_cpu/lib/python3.10/site-packages/huggingface_hub/file_download.py:541, in http_get(url, temp_file, proxies, resume_size, headers, timeout, max_retries, expected_size)
#     531     displayed_name = f"(…){displayed_name[-20:]}"
#     533 progress = tqdm(
#     534     unit="B",
#     535     unit_scale=True,
#    (...)
#     539     disable=bool(logger.getEffectiveLevel() == logging.NOTSET),
#     540 )
# --> 541 for chunk in r.iter_content(chunk_size=10 * 1024 * 1024):
#     542     if chunk:  # filter out keep-alive new chunks
#     543         progress.update(len(chunk))
#
# File ~/miniconda3/envs/tf_cpu/lib/python3.10/site-packages/requests/models.py:816, in Response.iter_content.<locals>.generate()
#     814 if hasattr(self.raw, "stream"):
#     815     try:
# --> 816         yield from self.raw.stream(chunk_size, decode_content=True)
#     817     except ProtocolError as e:
#     818         raise ChunkedEncodingError(e)
#
# File ~/miniconda3/envs/tf_cpu/lib/python3.10/site-packages/urllib3/response.py:628, in HTTPResponse.stream(self, amt, decode_content)
#     626 else:
#     627     while not is_fp_closed(self._fp):
# --> 628         data = self.read(amt=amt, decode_content=decode_content)
#     630         if data:
#     631             yield data
#
# File ~/miniconda3/envs/tf_cpu/lib/python3.10/site-packages/urllib3/response.py:567, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     564 fp_closed = getattr(self._fp, "closed", False)
#     566 with self._error_catcher():
# --> 567     data = self._fp_read(amt) if not fp_closed else b""
#     568     if amt is None:
#     569         flush_decoder = True
#
# File ~/miniconda3/envs/tf_cpu/lib/python3.10/site-packages/urllib3/response.py:533, in HTTPResponse._fp_read(self, amt)
#     530     return buffer.getvalue()
#     531 else:
#     532     # StringIO doesn't like amt=None
# --> 533     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File ~/miniconda3/envs/tf_cpu/lib/python3.10/http/client.py:465, in HTTPResponse.read(self, amt)
#     462 if self.length is not None and amt > self.length:
#     463     # clip the read to the "end of response"
#     464     amt = self.length
# --> 465 s = self.fp.read(amt)
#     466 if not s and amt:
#     467     # Ideally, we would raise IncompleteRead if the content-length
#     468     # wasn't satisfied, but it might break compatibility.
#     469     self._close_conn()
#
# File ~/miniconda3/envs/tf_cpu/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File ~/miniconda3/envs/tf_cpu/lib/python3.10/ssl.py:1274, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270     if flags != 0:
#    1271         raise ValueError(
#    1272           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273           self.__class__)
# -> 1274     return self.read(nbytes, buffer)
#    1275 else:
#    1276     return super().recv_into(buffer, nbytes, flags)
#
# File ~/miniconda3/envs/tf_cpu/lib/python3.10/ssl.py:1130, in SSLSocket.read(self, len, buffer)
#    1128 try:
#    1129     if buffer is not None:
# -> 1130         return self._sslobj.read(len, buffer)
#    1131     else:
#    1132         return self._sslobj.read(len)
#
# KeyboardInterrupt:
